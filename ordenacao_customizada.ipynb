# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor

    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False
        return self._codigo == outro._codigo and self._saldo == outro._saldo
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

# %%
c1 = ContaSalario(3)
c2 = ContaSalario(8)
c3 = ContaSalario(5)

c1.deposita(530)
c2.deposita(150)
c3.deposita(450)

contas = [c1, c2, c3]

for conta in contas:
    print(conta)

# c1 < c2 - Erro, na classe não há um comparador para os objetos

def extrai_saldo(conta):
    return conta._saldo

print(sorted(contas, key=extrai_saldo))

for conta in sorted(contas, key=extrai_saldo):
    print(conta)
# Out:
# codigo: 3. saldo: 530
# codigo: 8. saldo: 150
# codigo: 5. saldo: 450
# [<__main__.ContaSalario object at 0x7f12dca66340>, <__main__.ContaSalario object at 0x7f12dca66a30>, <__main__.ContaSalario object at 0x7f12dca664c0>]
# codigo: 8. saldo: 150
# codigo: 5. saldo: 450
# codigo: 3. saldo: 530

# %%
from operator import attrgetter

for conta in sorted(contas, key=attrgetter("_saldo")):
    print(conta)
# Out:
# codigo: 8. saldo: 150
# codigo: 5. saldo: 450
# codigo: 3. saldo: 530

# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor

    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False
        return self._codigo == outro._codigo and self._saldo == outro._saldo
    
    def __lt__(self, outro):
        return self._saldo < outro._saldo
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

# %%
c1 = ContaSalario(3)
c2 = ContaSalario(8)
c3 = ContaSalario(5)

c1.deposita(530)
c2.deposita(150)
c3.deposita(450)

contas = [c1, c2, c3]

print("c2 é menor que c1",c2 < c1)
print("c1 é menor que c2",c1 < c2)
# Out:
# c2 é menor que c1 True
# c1 é menor que c2 False

# %%
for conta in sorted(contas):
    print(conta)
print("\n")
for conta in sorted(contas, reverse=True):
    print(conta)
# Out:
# codigo: 8. saldo: 150
# codigo: 5. saldo: 450
# codigo: 3. saldo: 530
#
#
# codigo: 3. saldo: 530
# codigo: 5. saldo: 450
# codigo: 8. saldo: 150
