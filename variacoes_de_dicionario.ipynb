# %%
meu_texto = "Bem vindo meu nome Pablo eu gosto muito de nomes e tenho o meu cachorro e gosto muito de cachorro"
meu_texto = meu_texto.lower()

aparicoes = {}

for palavra in meu_texto.split():
    ate_agora = aparicoes.get(palavra, 0)
    aparicoes[palavra] = ate_agora + 1

aparicoes
# Out:
# {'bem': 1,
#  'vindo': 1,
#  'meu': 2,
#  'nome': 1,
#  'pablo': 1,
#  'eu': 1,
#  'gosto': 2,
#  'muito': 2,
#  'de': 2,
#  'nomes': 1,
#  'e': 2,
#  'tenho': 1,
#  'o': 1,
#  'cachorro': 2}

# %%
from collections import defaultdict

aparicoes = defaultdict(int)

for palavra in meu_texto.split():
    ate_agora = aparicoes[palavra]
    aparicoes[palavra] = ate_agora + 1

aparicoes
# Out:
# defaultdict(int,
#             {'bem': 1,
#              'vindo': 1,
#              'meu': 2,
#              'nome': 1,
#              'pablo': 1,
#              'eu': 1,
#              'gosto': 2,
#              'muito': 2,
#              'de': 2,
#              'nomes': 1,
#              'e': 2,
#              'tenho': 1,
#              'o': 1,
#              'cachorro': 2})

# %%
aparicoes = defaultdict(int)

for palavra in meu_texto.split():
    aparicoes[palavra] += 1

aparicoes
# Out:
# defaultdict(int,
#             {'bem': 1,
#              'vindo': 1,
#              'meu': 2,
#              'nome': 1,
#              'pablo': 1,
#              'eu': 1,
#              'gosto': 2,
#              'muito': 2,
#              'de': 2,
#              'nomes': 1,
#              'e': 2,
#              'tenho': 1,
#              'o': 1,
#              'cachorro': 2})

# %%
class Conta:

    def __init__(self):
        print(f"Criando uma conta")

contas = defaultdict(Conta)
contas[15]
contas
# Out:
# Criando uma conta
# defaultdict(__main__.Conta, {15: <__main__.Conta at 0x7feefc46dc70>})

# %%
from collections import Counter

aparicoes = Counter()
for palavra in meu_texto.split():
    aparicoes[palavra] += 1

aparicoes
# Out:
# Counter({'bem': 1,
#          'vindo': 1,
#          'meu': 2,
#          'nome': 1,
#          'pablo': 1,
#          'eu': 1,
#          'gosto': 2,
#          'muito': 2,
#          'de': 2,
#          'nomes': 1,
#          'e': 2,
#          'tenho': 1,
#          'o': 1,
#          'cachorro': 2})

# %%
aparicoes = Counter(meu_texto.split())
aparicoes
# Out:
# Counter({'bem': 1,
#          'vindo': 1,
#          'meu': 2,
#          'nome': 1,
#          'pablo': 1,
#          'eu': 1,
#          'gosto': 2,
#          'muito': 2,
#          'de': 2,
#          'nomes': 1,
#          'e': 2,
#          'tenho': 1,
#          'o': 1,
#          'cachorro': 2})
