# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

# %%
c1 = ContaSalario(1)
c2 = ContaSalario(1)

print(c1)
print(c2)

print(f"Equals: {c1 == c2}")
# Out:
# codigo: 1. saldo: 0
# codigo: 1. saldo: 0
# Equals: False

# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor

    def __eq__(self, outro):
        return self._codigo == outro._codigo
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

# %%
cnt1 = ContaSalario(1)
cnt2 = ContaSalario(1)

print(cnt1)
print(cnt2)

print(f"Equals: {cnt1 == cnt2}")
contas = [cnt1]
cnt2 in contas
# Out:
# codigo: 1. saldo: 0
# codigo: 1. saldo: 0
# Equals: True
# True

# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor

    def __eq__(self, outro):
        return self._codigo == outro._codigo and self._saldo == outro._saldo
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

# %%
cnt1 = ContaSalario(1)
cnt2 = ContaSalario(1)

print(cnt1)
print(cnt2)

print(f"Equals: {cnt1 == cnt2}")
contas = [cnt1]
print(cnt2 in contas)
cnt2.deposita(100)
print(cnt2 in contas)
# Out:
# codigo: 1. saldo: 0
# codigo: 1. saldo: 0
# Equals: True
# True
# False

# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor

    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False
        return self._codigo == outro._codigo and self._saldo == outro._saldo
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

class ContaCorrente:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

# %%
c1 = ContaSalario(1)
c2 = ContaCorrente(1)
print(f"Equals: {c1 == c2}")
# Out:
# Equals: False

# %%
class ContaSalario:

    def __init__(self, codigo):
        self._codigo = codigo
        self._saldo = 0

    def deposita(self, valor):
        self._saldo += valor

    def __eq__(self, outro):
        if type(outro) != ContaSalario:
            return False
        elif not isinstance(outro, ContaSalario):
            return False
        return self._codigo == outro._codigo and self._saldo == outro._saldo
    
    def __str__(self):
        return f'codigo: {self._codigo}. saldo: {self._saldo}'

class ContaMultiplas(ContaSalario):
    pass

# %%
c1 = ContaSalario(1)
c2 = ContaMultiplas(1)
print(f"Equals: {c1 == c2}")
# Out:
# Equals: True
